# %%
# !pip install langchain_huggingface
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.36.0)
# Collecting langchain-core<2.0.0,>=1.2.0 (from langchain_huggingface)
#   Downloading langchain_core-1.2.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.22.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (1.2.1rc0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (8.5.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.0->langchain_huggingface)
#   Downloading uuid_utils-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2025.11.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain_huggingface) (0.16.0)
# Downloading langchain_huggingface-1.2.0-py3-none-any.whl (30 kB)
# Downloading langchain_core-1.2.6-py3-none-any.whl (489 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.1/489.1 kB 17.0 MB/s eta 0:00:00
# Downloading uuid_utils-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.7/343.7 kB 16.3 MB/s eta 0:00:00
# Installing collected packages: uuid-utils, langchain-core, langchain_huggingface
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.2.6 which is incompatible.
# langchain 0.3.27 requires SQLAlchemy<3,>=1.4, but you have sqlalchemy 1.2.19 which is incompatible.
# Successfully installed langchain-core-1.2.6 langchain_huggingface-1.2.0 uuid-utils-0.12.0

# %%
import os

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
os.environ["HF_TOKEN"] = user_secrets.get_secret("HUGGINGFACE_API_KEY")

# %% [markdown]
# # Models

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
)
model = ChatHuggingFace(llm=llm)
result = model.invoke("What is the capital of India.")
print(result.content)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
document = [
    "Delhi is the capital of India",
    "Kolkata is the capital of West Bengal",
    "Paris is the capital of France"
]

vector = embedding_model.embed_documents(document)
print(str(vector))
# Out:
# 2026-01-07 12:01:14.837008: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767787275.307311      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767787275.462285      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767787276.688046      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767787276.688096      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767787276.688100      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767787276.688103      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [[0.043549541383981705, 0.023877229541540146, -0.045241255313158035, 0.035404957830905914, -0.016651036217808723, -0.06554819643497467, 0.076260045170784, 0.009940397925674915, -0.001963227754458785, -0.027022695168852806, 0.00738556869328022, -0.12068238109350204, 0.0640484169125557, -0.06795034557580948, 0.03638886287808418, -0.0780777707695961, 0.033184148371219635, 0.08175564557313919, 0.07336147874593735, -0.07802221924066544, -0.020921166986227036, 0.03573276475071907, -0.008563303388655186, -0.037455108016729355, 0.00043885112972930074, 0.053464263677597046, 0.005293607711791992, -0.016870398074388504, -0.000413047760957852, 0.0010301906149834394, 0.06669675558805466, 0.004223186522722244, -0.022522566840052605, -0.002101559890434146, -0.055947814136743546, 0.01686999760568142, -0.1295160949230194, 0.06496334075927734, 0.17288093268871307, -0.11778349429368973, 0.03644103556871414, -0.000677512027323246, 0.07786679267883301, -0.028167517855763435, 0.03655537590384483, -0.023698804900050163, -0.02790212444961071, -0.004656855948269367, -0.011188924312591553, -0.02649613469839096, 0.06156330928206444, -0.048177219927310944, -0.07787912338972092, 0.03313848003745079, 0.02449951134622097, 0.04385222867131233, -0.032409247010946274, -0.04225396364927292, -0.004053812008351088, 0.030118506401777267, -0.01364248339086771, 0.043029751628637314, -0.024779796600341797, 0.022215483710169792, 0.0875730887055397, 0.012538780458271503, 0.038281045854091644, -0.015482554212212563, 0.014035405591130257, -0.020649679005146027, 0.016255756840109825, -0.012246188707649708, 0.02638865076005459, 0.01704891212284565, -0.012853015214204788, -0.07506397366523743, -0.03262092545628548, 0.07490301132202148, 0.014196847565472126, 0.03280464932322502, -0.01816450245678425, 0.028512436896562576, 0.028033340349793434, 0.08259157091379166, -0.09775902330875397, 0.008714078925549984, -0.04082169011235237, -0.01606968231499195, -0.0035580205731093884, -0.04325287044048309, 0.06346108764410019, 0.07535665482282639, -0.06780531257390976, 0.0011726041557267308, -0.06065615266561508, -0.035546790808439255, -0.07726342976093292, 0.049065664410591125, -0.01873236894607544, 0.023686159402132034, 0.02215038798749447, -0.029883775860071182, -0.09658297151327133, 0.015421693213284016, -0.051165513694286346, -0.07261940091848373, 0.0553908534348011, -0.07977937906980515, 0.007415558211505413, -0.015443813055753708, -0.05476999655365944, 0.012057463638484478, -0.048711374402046204, -0.04038207605481148, -0.0003923961194232106, 0.018431853502988815, 0.01827819086611271, -0.011221233755350113, -0.02124432660639286, -0.02254820056259632, -0.07889121025800705, 0.023742057383060455, -0.01836337335407734, -0.0690629631280899, -0.06974615901708603, -0.1075616106390953, -0.03640320897102356, -6.297900532994475e-33, -0.10432390868663788, -0.030779317021369934, 0.0778890922665596, 0.06358230113983154, -0.0018615768058225513, 0.039968594908714294, 0.057966191321611404, -0.08833266794681549, -0.0035982532426714897, -0.06283364444971085, 0.01078797411173582, -0.14935792982578278, -0.008195623755455017, -0.10685470700263977, 0.0856679305434227, 0.023375628516077995, 0.021146230399608612, -0.0031016606371849775, -0.010256240144371986, 0.008449815213680267, -0.028259269893169403, -0.019984189420938492, 0.006321839056909084, -0.060975804924964905, 0.061109140515327454, -0.02171214483678341, 0.0465342253446579, 0.053876761347055435, 0.053162503987550735, 0.019443286582827568, 0.025639237836003304, 0.0882863700389862, -0.016172325238585472, 0.027486372739076614, 0.009730429388582706, 0.002538608852773905, 0.01886855624616146, 0.024688508361577988, 0.0028549227863550186, 0.017087124288082123, -0.05583006888628006, 0.044804636389017105, -0.027243992313742638, -0.021476704627275467, -0.0016898714238777757, 0.08229093253612518, -0.020781198516488075, 0.05805094540119171, 0.020494626834988594, -0.004589486867189407, 0.0021169709507375956, 0.018269741907715797, -0.012833992950618267, -0.0 ...

# %% [markdown]
# # Chat Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_template = ChatPromptTemplate([
    ('system', 'You are a helpful {domain} expert'),
    ('human', 'Explain in simple terms, what is {topic}')
])

prompt = chat_template.invoke({'domain': 'cricket', 'topic': 'Wicket'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful cricket expert', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain in simple terms, what is Wicket', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm= HuggingFaceEndpoint(repo_id="meta-llama/Meta-Llama-3-8B-Instruct")
chat_model = ChatHuggingFace(llm=llm)

chat_history = [
    SystemMessage(content='You are very helpful AI assistant.')
]

while True:
    user_input = input('You : ')
    chat_history.append(HumanMessage(content=user_input))
    if user_input == 'exit':
        break
    result = chat_model.invoke(chat_history)
    chat_history.append(AIMessage(content=result.content))
    print("AI : ", result.content)

print(chat_history)
# Out:
# You :  Hello
# AI :  It's nice to meet you. Is there something I can help you with or would you like to chat?
# You :  What is the capital of India
# AI :  The capital of India is New Delhi.
# You :  Tell me something about Punjab
# AI :  Punjab is a state located in the northern part of India. It is a culturally rich and historically significant region that is known for its vibrant culture, delicious cuisine, and stunning landscapes.
#
# Here are some interesting facts about Punjab:
#
# 1. **Location**: Punjab is situated in the northern part of India, bordering Pakistan to the west and the states of Haryana, Himachal Pradesh, and Jammu and Kashmir to the east, north, and south.
# 2. **Language**: The official language of Punjab is Punjabi, which is spoken by over 30 million people worldwide.
# 3. **Cuisine**: Punjabi cuisine is famous for its rich flavors, aromas, and spices. Popular dishes include sarson ka saag (mustard greens), makki di roti (corn bread), butter chicken, and tandoori naan.
# 4. **History**: Punjab has a rich historical heritage, with evidence of human habitation dating back to the Indus Valley Civilization (3300-1300 BCE). The region was also a major center of trade and commerce during the ancient Silk Road era.
# 5. **Cities**: Punjab's largest city is Chandigarh, the capital of the state, which is known for its well-planned architecture and beautiful gardens. Other major cities include Ludhiana, Amritsar, and Jalandhar.
# 6. **Tourism**: Punjab is home to several popular tourist attractions, including the Golden Temple (Harmandir Sahib) in Amritsar, the Wagah border, and the picturesque hill stations of Shimla and Dharamsala.
# 7. **Agriculture**: Punjab is known as the "breadbasket of India" due to its rich agricultural land and fertile soil. The region is a major producer of crops such as wheat, rice, and sugarcane.
#
# Overall, Punjab is a region that is steeped in history, culture, and natural beauty, making it a fascinating place to explore and learn about.
# You :  Nice
# AI :  I'm glad you enjoyed learning a bit about Punjab. If you have any more questions or want to explore more about India or other topics, feel free to ask!
# You :  exit
# [SystemMessage(content='You are very helpful AI assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello', additional_kwargs={}, response_metadata={}), AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of India', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Tell me something about Punjab', additional_kwargs={}, response_metadata={}), AIMessage(content='Punjab is a state located in the northern part of India. It is a culturally rich and historically significant region that is known for its vibrant culture, delicious cuisine, and stunning landscapes.\n\nHere are some interesting facts about Punjab:\n\n1. **Location**: Punjab is situated in the northern part of India, bordering Pakistan to the west and the states of Haryana, Himachal Pradesh, and Jammu and Kashmir to the east, north, and south.\n2. **Language**: The official language of Punjab is Punjabi, which is spoken by over 30 million people worldwide.\n3. **Cuisine**: Punjabi cuisine is famous for its rich flavors, aromas, and spices. Popular dishes include sarson ka saag (mustard greens), makki di roti (corn bread), butter chicken, and tandoori naan.\n4. **History**: Punjab has a rich historical heritage, with evidence of human habitation dating back to the Indus Valley Civilization (3300-1300 BCE). The region was also a major center of trade and commerce during the ancient Silk Road era.\n5. **Cities**: Punjab\'s largest city is Chandigarh, the capital of the state, which is known for its well-planned architecture and beautiful gardens. Other major cities include Ludhiana, Amritsar, and Jalandhar.\n6. **Tourism**: Punjab is home to several popular tourist attractions, including the Golden Temple (Harmandir Sahib) in Amritsar, the Wagah border, and the picturesque hill stations of Shimla and Dharamsala.\n7. **Agriculture**: Punjab is known as the "breadbasket of India" due to its rich agricultural land and fertile soil. The region is a major producer of crops such as wheat, rice, and sugarcane.\n\nOverall, Punjab is a region that is steeped in history, culture, and natural beauty, making it a fascinating place to explore and learn about.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Nice', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm glad you enjoyed learning a bit about Punjab. If you have any more questions or want to explore more about India or other topics, feel free to ask!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='exit', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
chat_template = ChatPromptTemplate([
    ('system','You are a helpful customer support agent'),
    MessagesPlaceholder(variable_name='chat_history'),
    ('human','{query}')
])

prompt = chat_template.invoke({'chat_history': chat_history, 'query': 'Tell me about history of punjab'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful customer support agent', additional_kwargs={}, response_metadata={}), SystemMessage(content='You are very helpful AI assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello', additional_kwargs={}, response_metadata={}), AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of India', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Tell me something about Punjab', additional_kwargs={}, response_metadata={}), AIMessage(content='Punjab is a state located in the northern part of India. It is a culturally rich and historically significant region that is known for its vibrant culture, delicious cuisine, and stunning landscapes.\n\nHere are some interesting facts about Punjab:\n\n1. **Location**: Punjab is situated in the northern part of India, bordering Pakistan to the west and the states of Haryana, Himachal Pradesh, and Jammu and Kashmir to the east, north, and south.\n2. **Language**: The official language of Punjab is Punjabi, which is spoken by over 30 million people worldwide.\n3. **Cuisine**: Punjabi cuisine is famous for its rich flavors, aromas, and spices. Popular dishes include sarson ka saag (mustard greens), makki di roti (corn bread), butter chicken, and tandoori naan.\n4. **History**: Punjab has a rich historical heritage, with evidence of human habitation dating back to the Indus Valley Civilization (3300-1300 BCE). The region was also a major center of trade and commerce during the ancient Silk Road era.\n5. **Cities**: Punjab\'s largest city is Chandigarh, the capital of the state, which is known for its well-planned architecture and beautiful gardens. Other major cities include Ludhiana, Amritsar, and Jalandhar.\n6. **Tourism**: Punjab is home to several popular tourist attractions, including the Golden Temple (Harmandir Sahib) in Amritsar, the Wagah border, and the picturesque hill stations of Shimla and Dharamsala.\n7. **Agriculture**: Punjab is known as the "breadbasket of India" due to its rich agricultural land and fertile soil. The region is a major producer of crops such as wheat, rice, and sugarcane.\n\nOverall, Punjab is a region that is steeped in history, culture, and natural beauty, making it a fascinating place to explore and learn about.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Nice', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm glad you enjoyed learning a bit about Punjab. If you have any more questions or want to explore more about India or other topics, feel free to ask!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='exit', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about history of punjab', additional_kwargs={}, response_metadata={})]

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate

llm = HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct"
)
chat_model = ChatHuggingFace(llm=llm)

template = PromptTemplate(
    template = 'Greet this person in 5 languages. The name of the person is {name}',
    input_variables=['name']
)

prompt = template.invoke({'name': 'Shivam'})
result = model.invoke(prompt)
print(result.content)
# Out:
# Here are greetings for Shivam in 5 different languages:
#
# 1. **Hello in English**: Hello, Shivam!
# 2. **Bonjour in French**: Bonjour, Shivam!
# 3. **Hola in Spanish**: Hola, Shivam!
# 4. **Ciao in Italian**: Ciao, Shivam!
# 5. **Namaste in Hindi** (since Shivam is an Indian name): नमस्ते Shivam! (Namaste Shivam!)

# %% [markdown]
# # Output Parser

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
)

chat_model = ChatHuggingFace(llm = llm)

parser = JsonOutputParser()

template = PromptTemplate(
    template='Give me 5 facts about {topic} \n {format_instruction}',
    input_variables=['topic'],
    partial_variables={'format_instruction': parser.get_format_instructions()}
)

chain = template | chat_model | parser
result = chain.invoke({'topic': 'black hole'})
print(result)
# Out:
# {'fact1': {'title': 'What is a Black Hole?', 'description': 'A black hole is a region in space where the gravitational pull is so strong that nothing, including light, can escape. It is formed when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of spacetime.'}, 'fact2': {'title': 'Types of Black Holes', 'description': 'There are four types of black holes: stellar black holes (formed from the collapse of individual stars), supermassive black holes (found at the centers of galaxies), intermediate-mass black holes (with masses between those of stellar and supermassive black holes), and miniature black holes (hypothetical black holes with masses smaller than stellar black holes).'}, 'fact3': {'title': 'Event Horizon', 'description': "The event horizon is the point of no return around a black hole. Any matter or radiation that crosses the event horizon is trapped by the black hole's gravity and cannot escape. The event horizon is not a physical boundary but rather a mathematical concept that marks the boundary beyond which the gravitational pull is so strong that escape is impossible."}, 'fact4': {'title': 'Hawking Radiation', 'description': 'In 1974, Stephen Hawking proposed that black holes emit radiation, now known as Hawking radiation, due to quantum effects near the event horizon. This theory predicts that black holes have a temperature and entropy, and over time, they will evaporate and eventually disappear.'}, 'fact5': {'title': 'Detection of Black Holes', 'description': 'Black holes are difficult to detect directly, but their presence can be inferred by observing the effects they have on the surrounding environment, such as the motion of stars or gas. The detection of gravitational waves by LIGO and VIRGO collaborations in 2015 provided strong evidence for the existence of black holes, confirming a key prediction made by Albert Einstein a century ago.'}}

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
)
chat_model = ChatHuggingFace(llm = llm)

class Person(BaseModel):
    name: str = Field(description="Name of the person")
    age: int = Field(description="Age, must be >= 18")
    city: str = Field(description="City of residence")

parser = JsonOutputParser(pydantic_object=Person)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You MUST return only valid JSON. No text, no markdown."),
    ("human", "Generate a person from {place}.\n{format_instructions}")
])

prompt = prompt.partial(format_instructions=parser.get_format_instructions())

chain = prompt | chat_model | parser

result = chain.invoke({"place": "India"})
print(result)
# Out:
# {'name': 'Rohan Kumar', 'age': 25, 'city': 'New Delhi'}

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct"
)
chat_model = ChatHuggingFace(llm = llm)

template1 = PromptTemplate(
    template = 'Write a detailed report on the {topic}',
    input_variable = ['topic']
)

template2 = PromptTemplate(
    template = 'Write a 5 line summary on the following text. /n {text}',
    input_variable = ['text']
)

parser = StrOutputParser()
chain = template1 | chat_model | parser | template2 | chat_model | parser
result = chain.invoke({'topic': 'Black Hole'})
print(result)
# Out:
# Here is a 5-line summary of the given text:
#
# Black holes are mysterious objects in space where gravity is so strong that nothing, including light, can escape. They are formed when a star collapses, warping the fabric of spacetime and creating a boundary called the event horizon. There are four types of black holes: stellar, supermassive, intermediate-mass, and primordial. Black holes have unique properties, including a singularity at their center and the emission of Hawking radiation due to quantum effects. These enigmatic objects continue to fascinate scientists and astronomers, with ongoing research expanding our understanding of their behavior and characteristics.

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

llm = HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct"
)
chat_model = ChatHuggingFace(llm=llm)

schema = [
    ResponseSchema(name='fact_1', description='Fact 1 about the topic'),
    ResponseSchema(name='fact_2', description='Fact 2 about the topic'),
    ResponseSchema(name='fact_3', description='Fact 3 about the topic'),
]

parser = StructuredOutputParser.from_response_schemas(schema)

template = PromptTemplate(
    template='Give 3 fact about {topic} \n {format_instruction}',
    input_variables=['topic'],
    partial_variables={'format_instruction':parser.get_format_instructions()}
)

chain = template | chat_model | parser
result = chain.invoke({'topic':'black hole'})
print(result)
# Out:
# {'fact_1': 'A black hole is formed when a massive star collapses in on itself and its gravity becomes so strong that nothing, not even light, can escape. This process is known as a supernova explosion.', 'fact_2': "The point of no return around a black hole is called the event horizon. Once something crosses the event horizon, it is trapped by the black hole's gravity and cannot escape.", 'fact_3': 'The center of a black hole is called a singularity, where the density and gravity are infinite. This is where the laws of physics as we know them break down.'}

# %% [markdown]
# # Chains

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = PromptTemplate(
    template='Generate 5 interesting facts about {topic}',
    input_variables=['topic']
)

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
)
chat_modal = ChatHuggingFace(llm=llm)

parser = StrOutputParser()

chain = prompt | chat_modal | parser
result = chain.invoke({'topic': 'ISRO'})
print(result)
# Out:
# Here are 5 interesting facts about ISRO:
#
# 1. **ISRO's First Successful Launch**: ISRO's first successful launch was the Rohini rocket on August 18, 1980. The Rohini rocket was a sounding rocket that reached an altitude of 86 km. This marked a significant milestone in India's space exploration history.
#
# 2. **Mangalyaan Mission**: ISRO's Mars Orbiter Mission, also known as Mangalyaan, was launched on November 5, 2013. This mission aimed to study the Martian atmosphere and geology. Mangalyaan was launched at a cost of just $74 million, making it one of the most affordable interplanetary missions ever.
#
# 3. **Reusable Launch Vehicle**: ISRO is working on a reusable launch vehicle called the Reusable Launch Vehicle Technology Demonstrator (RLV-TD). The test mission of RLV-TD was conducted on May 23, 2016. The vehicle successfully demonstrated autonomous flight and landing, paving the way for more efficient and cost-effective space missions.
#
# 4. **Cartosat-2 Series**: ISRO's Cartosat-2 series is a family of operational remote-sensing satellites designed to capture high-resolution images of the Earth's surface. The Cartosat-2 series has been used to create detailed maps of the Indian population, track land use changes, and monitor natural disasters.
#
# 5. **Aryabhata Satellite**: ISRO's Aryabhata satellite was launched on April 19, 1975, and was India's first satellite. The Aryabhata satellite was a scientific research satellite that studied the Earth's magnetic field and the X-ray solar spectrum. The satellite was named after the ancient Indian mathematician and astronomer Aryabhata, who proposed the concept of a spherical Earth.

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt1 = PromptTemplate(
    template = 'Generate a detailed report on {topic}',
    input_variables = ['topic']
)

prompt2 = PromptTemplate(
    template = 'Generate me a 5 pointer symmary from the following text \n {text}',
    input_variables = ['text']
)

llm = HuggingFaceEndpoint(
    repo_id='meta-llama/Meta-Llama-3-8B-Instruct'
)
chat_modal = ChatHuggingFace(llm=llm)

parser = StrOutputParser()

chain = prompt1 | chat_modal | parser | prompt2 | chat_modal | parser
result = chain.invoke({'topic': 'ISRO'})
print(result)
# Out:
# Here is a 5-pointer summary of the Indian Space Research Organisation (ISRO) based on the given text:
#
# 1. **Establishment and Headquarters**: ISRO was established in 1969 and is headquartered in Bengaluru, India, with a hierarchical structure consisting of several departments and centres.
#
# 2. **Mission and Objectives**: ISRO's mission is to explore space and use space technology for humanity's benefit, with objectives including space research, space exploration, space applications, and launch services.
#
# 3. **Organisational Structure**: ISRO's organisational structure includes the Director General (DG), Chairman, Space Commission, and Directors of various centres such as VSSC, NRSC, SAC, and LEOS.
#
# 4. **Programmes and Projects**: ISRO has undertaken numerous programmes and projects, including space research, space exploration, and space applications, with a focus on advancing our understanding of the universe and improving life on Earth.
#
# 5. **Contributions to Space Exploration**: ISRO is a leading space agency in Asia, having made significant contributions to space exploration, with achievements in various areas of space science and technology, and providing launch services for national and international customers.

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

llm = HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct"
)

chat_modal = ChatHuggingFace(llm=llm)

prompt1 = PromptTemplate(
    template="Generate short and simple notes from the following text \n {text}",
    input_variables=['text'] 
)

prompt2 = PromptTemplate(
    template="Generate 5 short question answers from the following text \n {text}",
    input_variables=['text']
)

prompt3 = PromptTemplate(
    template="Merge the provided notes and quiz into a single document \n notes -> {notes} and quiz -> {quiz}",
    input_variables=['notes', 'quiz']
)

parser = StrOutputParser()

parallel_chains = RunnableParallel({
    'notes': prompt1 | chat_modal | parser,
    'quiz': prompt2 | chat_modal | parser
})
merge_chain = prompt3 | chat_modal | parser
chain = parallel_chains | merge_chain

text = """
Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection.

The advantages of support vector machines are:

Effective in high dimensional spaces.

Still effective in cases where number of dimensions is greater than the number of samples.

Uses a subset of training points in the decision function (called support vectors), so it is also memory efficient.

Versatile: different Kernel functions can be specified for the decision function. Common kernels are provided, but it is also possible to specify custom kernels.

The disadvantages of support vector machines include:

If the number of features is much greater than the number of samples, avoid over-fitting in choosing Kernel functions and regularization term is crucial.

SVMs do not directly provide probability estimates, these are calculated using an expensive five-fold cross-validation (see Scores and probabilities, below).

The support vector machines in scikit-learn support both dense (numpy.ndarray and convertible to that by numpy.asarray) and sparse (any scipy.sparse) sample vectors as input. However, to use an SVM to make predictions for sparse data, it must have been fit on such data. For optimal performance, use C-ordered numpy.ndarray (dense) or scipy.sparse.csr_matrix (sparse) with dtype=float64.
"""

result = chain.invoke({'text': text})
print(result)
# Out:
# **Support Vector Machines (SVMs) Notes**
#
# **Overview**
#
# Support Vector Machines (SVMs) are supervised learning methods for classification, regression, and outlier detection.
#
# **Advantages**
#
# SVMs have several advantages, including:
#
# -   Effective in high-dimensional spaces: SVMs can handle cases where the number of dimensions is greater than the number of samples.
# -   Memory efficient: SVMs use a subset of training points, which makes them memory-efficient.
# -   Versatile: SVMs can be customized using various kernel functions, making them suitable for a wide range of problems.
#
# **Disadvantages**
#
# However, SVMs also have some disadvantages:
#
# -   Prone to overfitting in high-dimensional spaces: Choosing the right kernel and regularization terms is crucial to avoid overfitting.
# -   Do not provide direct probability estimates: SVMs do not provide direct probability estimates, which are calculated using an expensive five-fold cross-validation.
# -   Choosing kernel and regularization terms is crucial: Choosing the right kernel and regularization terms is crucial to achieve good performance.
#
# **Input Requirements**
#
# The SVMs in scikit-learn support the following input data:
#
# -   Dense and sparse sample vectors: SVMs can handle both dense and sparse sample vectors.
# -   Optimal performance with C-ordered numpy.ndarray (dense) or scipy.sparse.csr_matrix (sparse) with dtype=float64.
#
# **Quiz**
#
# Here are 5 short question answers based on the notes:
#
# **Q1: What type of learning methods are Support Vector Machines (SVMs)?**
# A1: SVMs are a set of supervised learning methods.
#
# **Q2: What are the advantages of using Support Vector Machines?**
# A2: They are effective in high-dimensional spaces, memory efficient, versatile, and can handle cases where the number of dimensions is greater than the number of samples.
#
# **Q3: Why is choosing the right Kernel function crucial for SVMs?**
# A3: It is crucial to avoid over-fitting, especially when the number of features is much greater than the number of samples.
#
# **Q4: What type of input data do the Support Vector Machines in scikit-learn support?**
# A4: They support both dense and sparse sample vectors, specifically C-ordered numpy.ndarray (dense) or scipy.sparse.csr_matrix (sparse) with dtype=float64 for optimal performance.
#
# **Q5: How do Support Vector Machines provide probability estimates?**
# A5: SVMs do not directly provide probability estimates, which are calculated using an expensive five-fold

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser
from langchain_core.runnables import RunnableBranch, RunnableLambda
from pydantic import BaseModel, Field
from typing import Literal

llm = HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct"
)

model = ChatHuggingFace(llm = llm)

parser = StrOutputParser()

class Feedback(BaseModel):

    sentiment: Literal['positive', 'negative'] = Field(description='Give the sentiment of the feedback')

parser2 = PydanticOutputParser(pydantic_object=Feedback)

prompt1 = PromptTemplate(
    template='Classify the sentiment of the following feedback text into postive or negative \n {feedback} \n {format_instruction}',
    input_variables=['feedback'],
    partial_variables={'format_instruction':parser2.get_format_instructions()}
)

classifier_chain = prompt1 | model | parser2

prompt2 = PromptTemplate(
    template='Write an appropriate response to this positive feedback \n {feedback}',
    input_variables=['feedback']
)

prompt3 = PromptTemplate(
    template='Write an appropriate response to this negative feedback \n {feedback}',
    input_variables=['feedback']
)

branch_chain = RunnableBranch(
    (lambda x:x.sentiment == 'positive', prompt2 | model | parser),
    (lambda x:x.sentiment == 'negative', prompt3 | model | parser),
    RunnableLambda(lambda x: "could not find sentiment")
)

chain = classifier_chain | branch_chain

print(chain.invoke({'feedback': 'This is a beautiful phone'}))
# Out:
# "Thank you so much for your kind words! I'm glad you're satisfied with the [service/product/experience]. It's always rewarding to know that we've made a positive impact. If there's anything else I can help with, please don't hesitate to reach out."
